# %%
from get_variables import GetVariables
import pandas as pd

# %%
path = r"datasets/Cajas_Municipales/EF/2014/C-1101-di2014.xls"

# %%
df = pd.read_excel(path,header=None)
df
# Out:
#                                           0    1            2            3   \
# 0                                        NaN  NaN          NaN          NaN
# 1         Balance General por Caja Municipal  NaN          NaN          NaN
# 2                        2014-12-31 00:00:00  NaN          NaN          NaN
# 3                 (En Miles de Nuevos Soles)  NaN          NaN          NaN
# 4                  Actualizado al 05.03.2015  NaN          NaN          NaN
# ..                                       ...  ...          ...          ...
# 128       Instrumentos Financieros Derivados    0  72713.61071  72713.61071
# 129               Otras Cuentas Contingentes    0            0            0
# 130                                      NaN  NaN          NaN          NaN
# 131       Tipo de Cambio Contable: S/. 2.986  NaN          NaN          NaN
# 132  1/ Incluye gastos devengados por pagar.  NaN          NaN          NaN
#
# ...

# %%
instance = GetVariables("datasest","EF","Cajas_Municipales")
df = instance.clean_firts_moment(df).reset_index(drop=True)
df
# Out:
#                                                     0              1   \
# 0                   Balance General por Caja Municipal            NaN
# 1                                  2014-12-31 00:00:00            NaN
# 2                           (En Miles de Nuevos Soles)            NaN
# 3                            Actualizado al 05.03.2015            NaN
# 4                                               Activo  CMAC Arequipa
# ..                                                 ...            ...
# 98      Líneas de Crédito no Utilizadas y Créditos ...   282820.92685
# 99                  Instrumentos Financieros Derivados              0
# 100                         Otras Cuentas Contingentes              0
# 101                 Tipo de Cambio Contable: S/. 2.986            NaN
# 102            1/ Incluye gastos devengados por pagar.            NaN
#
#               2             3             5    6             7   \
# ...

# %%
col,row = instance.get_col_row_activo(df.iloc[:15,:3])
col,row
# Out:
# (0, 4)

# %%
df = df.iloc[row:,col:].copy(deep=True).reset_index(drop=True)
df
# Out:
#                                                    0              1   \
# 0                                              Activo  CMAC Arequipa
# 1                                                 NaN             MN
# 2                                          DISPONIBLE   546109.67028
# 3                                                Caja     80876.7626
# 4                             Bancos y Corresponsales   463030.00392
# ..                                                ...            ...
# 94     Líneas de Crédito no Utilizadas y Créditos ...   282820.92685
# 95                 Instrumentos Financieros Derivados              0
# 96                         Otras Cuentas Contingentes              0
# 97                 Tipo de Cambio Contable: S/. 2.986            NaN
# 98            1/ Incluye gastos devengados por pagar.            NaN
#
#               2             3             5             6             7   \
# ...

# %%
df.iloc[0,0]="ACTIVO"
df.iloc[1,0] = "MONEDA"
df
# Out:
#                                                    0              1   \
# 0                                              ACTIVO  CMAC Arequipa
# 1                                              MONEDA             MN
# 2                                          DISPONIBLE   546109.67028
# 3                                                Caja     80876.7626
# 4                             Bancos y Corresponsales   463030.00392
# ..                                                ...            ...
# 94     Líneas de Crédito no Utilizadas y Créditos ...   282820.92685
# 95                 Instrumentos Financieros Derivados              0
# 96                         Otras Cuentas Contingentes              0
# 97                 Tipo de Cambio Contable: S/. 2.986            NaN
# 98            1/ Incluye gastos devengados por pagar.            NaN
#
#               2             3             5             6             7   \
# ...

# %%
df = instance.get_data_total(df)
df.dropna(inplace=True)
df.reset_index(drop=True)
# Out:
# 0                                              ACTIVO CMAC Arequipa  \
# 0                                          DISPONIBLE   751708.8375
# 1                                                Caja   98792.77329
# 2                             Bancos y Corresponsales  617847.01542
# 3                                               Canje    1357.45381
# 4                                               Otros   33711.59498
# ..                                                ...           ...
# 83                                       CONTINGENTES  371186.41001
# 84     Avales, Cartas Fianza, Cartas de Crédito y ...    2582.21993
# 85     Líneas de Crédito no Utilizadas y Créditos ...  295890.57937
# 86                 Instrumentos Financieros Derivados   72713.61071
# 87                         Otras Cuentas Contingentes             0
#
# 0     CMAC Cusco CMAC Del Santa CMAC Huancayo      CMAC Ica  CMAC Maynas  \
# 0    282409.0628     51825.6197  173336.07144  166985.36371  80600.53212
# ...

# %%
df = instance.get_variables(df)
df
# Out:
# 0                                              ACTIVO CMAC Arequipa  \
# 0                                          DISPONIBLE   751708.8375
# 1                                                Caja   98792.77329
# 2                             Bancos y Corresponsales  617847.01542
# 3                                               Canje    1357.45381
# 4                                               Otros   33711.59498
# ..                                                ...           ...
# 90                                       CONTINGENTES  371186.41001
# 91  Avales Cartas Fianza Cartas de Credito y Acept...    2582.21993
# 92  Lineas de Credito no Utilizadas y Creditos Con...  295890.57937
# 93                 Instrumentos Financieros Derivados   72713.61071
# 94                         Otras Cuentas Contingentes             0
#
# 0     CMAC Cusco CMAC Del Santa CMAC Huancayo      CMAC Ica  CMAC Maynas  \
# 0    282409.0628     51825.6197  173336.07144  166985.36371  80600.53212
# ...
